# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("data/train.csv", dtype={"Age": np.float64}, )
test  = pd.read_csv("data/test.csv", dtype={"Age": np.float64}, )

# %%
train["Name_len"]=train["Name"].apply(lambda x: len(x))
test["Name_len"]=test["Name"].apply(lambda x: len(x))

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  27.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Name_len
# 0      0         A/5 21171   7.2500   NaN        S        23
# 1      0          PC 17599  71.2833   C85        C        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22
# 3      0            113803  53.1000  C123        S        44
# 4      0            373450   8.0500   NaN        S        24
# 5      0            330877   8.4583   NaN        Q        16
# 6      0             17463  51.8625   E46        S        23
# 7      1            349909  21.0750   NaN        S        30
# 8      2            347742  11.1333   NaN        S        49
# 9      0            237736  30.0708   NaN        C        35

# %%
train_corr = train.corr()
train_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034759 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.061956 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.344489  0.083081  0.018443
# Age             0.034759 -0.061956 -0.344489  1.000000 -0.233396 -0.168329
# SibSp          -0.057527 -0.035322  0.083081 -0.233396  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.168329  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.099571  0.159651  0.216225
# Name_len       -0.012986  0.332350 -0.220001  0.044444  0.165019  0.252282
#
#                  Fare  Name_len
# PassengerId  0.012658 -0.012986
# Survived     0.257307  0.332350
# Pclass      -0.549500 -0.220001
# Age          0.099571  0.044444
# SibSp        0.159651  0.165019
# Parch        0.216225  0.252282
# Fare         1.000000  0.155832
# Name_len     0.155832  1.000000

# %%
def correct_data(train_data, test_data):
    
    # Make missing values ​​for training data from test data as well
    train_data.Age = train_data.Age.fillna(test_data.Age.median())
    train_data.Fare = train_data.Fare.fillna(test_data.Fare.median())
    train_data.Name_len = train_data.Name_len.fillna(test_data.Name_len.median())

    test_data.Age = test_data.Age.fillna(test_data.Age.median())
    test_data.Fare = test_data.Fare.fillna(test_data.Fare.median())    
    train_data = correct_data_common(train_data)
    test_data = correct_data_common(test_data)    
    return train_data,  test_data

def correct_data_common(titanic_data):
    titanic_data.Sex = titanic_data.Sex.replace(['male', 'female'], [0, 1])
    titanic_data.Embarked = titanic_data.Embarked.fillna("S")
    titanic_data.Embarked = titanic_data.Embarked.replace(['C', 'S', 'Q'], [0, 1, 2])

    return titanic_data

train_data,  test_data = correct_data(train, test)

# %%
train_corr = train.corr()
train_corr
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.034759 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.061956 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.344489  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.079306  0.114631
# Age             0.034759 -0.061956 -0.344489 -0.079306  1.000000 -0.233396
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.233396  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.168329  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.099571  0.159651
# Embarked       -0.017443 -0.125953  0.305762 -0.022521 -0.044949  0.030874
# Name_len       -0.012986  0.332350 -0.220001  0.448759  0.044444  0.165019
#
#                 Parch      Fare  Embarked  Name_len
# PassengerId -0.001652  0.012658 -0.017443 -0.012986
# Survived     0.081629  0.257307 -0.125953  0.332350
# Pclass       0.018443 -0.549500  0.305762 -0.220001
# Sex          0.245489  0.182333 -0.022521  0.448759
# Age         -0.168329  0.099571 -0.044949  0.044444
# SibSp        0.414838  0.159651  0.030874  0.165019
# Parch        1.000000  0.216225 -0.035957  0.252282
# Fare         0.216225  1.000000 -0.268865  0.155832
# Embarked    -0.035957 -0.268865  1.000000 -0.097896
# Name_len     0.252282  0.155832 -0.097896  1.000000

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score

# %%
predictors = ["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked", "Name_len"]

models = []

models.append(("LogisticRegression",LogisticRegression()))
models.append(("SVC",SVC()))
models.append(("LinearSVC",LinearSVC()))
models.append(("KNeighbors",KNeighborsClassifier()))
models.append(("DecisionTree",DecisionTreeClassifier()))
models.append(("RandomForest",RandomForestClassifier()))
models.append(("MLPClassifier",MLPClassifier(solver='lbfgs', random_state=0)))

# %%
results = []
names = []
for name,model in models:
    result = cross_val_score(model, train_data[predictors], train_data["Survived"],  cv=3)
    names.append(name)
    results.append(result)

# %%
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# ('LogisticRegression', 0.7890011223344556)
# ('SVC', 0.6352413019079686)
# ('LinearSVC', 0.6273849607182941)
# ('KNeighbors', 0.6902356902356902)
# ('DecisionTree', 0.734006734006734)
# ('RandomForest', 0.8002244668911335)
# ('MLPClassifier', 0.7901234567901234)

# %%
model = MLPClassifier(verbose= False, hidden_layer_sizes=(100,))
cross_val_score(model, train_data[predictors], train_data["Survived"],  cv=3).mean()
# Out:
# /Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.7934904601571269

# %%
alg = MLPClassifier(verbose= True, hidden_layer_sizes=(1000,))
alg.fit(train_data[predictors], train_data["Survived"])

predictions = alg.predict(test_data[predictors])

submission = pd.DataFrame({
        "PassengerId": test_data["PassengerId"],
        "Survived": predictions
    })

submission.to_csv('submission.csv', index=False)
# Out:
# Iteration 1, loss = 0.74485468
# Iteration 2, loss = 0.69088007
# Iteration 3, loss = 0.62729817
# Iteration 4, loss = 0.60307802
# Iteration 5, loss = 0.57100233
# Iteration 6, loss = 0.56915677
# Iteration 7, loss = 0.58434078
# Iteration 8, loss = 0.55838223
# Iteration 9, loss = 0.53739487
# Iteration 10, loss = 0.50589530
# Iteration 11, loss = 0.50531693
# Iteration 12, loss = 0.49772924
# Iteration 13, loss = 0.49484086
# Iteration 14, loss = 0.49107829
# Iteration 15, loss = 0.48001919
# Iteration 16, loss = 0.47298202
# Iteration 17, loss = 0.47159362
# Iteration 18, loss = 0.46502709
# Iteration 19, loss = 0.46254169
# Iteration 20, loss = 0.45888154
# Iteration 21, loss = 0.45272814
# Iteration 22, loss = 0.46280716
# Iteration 23, loss = 0.46861737
# Iteration 24, loss = 0.45501194
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
parameters = {
        'hidden_layer_sizes': [(10),(10,10),(10,10,10)],
        'activation'        : ['identity', 'logistic', 'tanh', 'relu'],
        'solver'            : ['lbfgs', 'sgd', 'adam'],
}
gsc = GridSearchCV(MLPClassifier(), parameters,cv=3, scoring='accuracy', n_jobs=-1)
gsc.fit(train_data[predictors], train_data["Survived"])
# Out:
# /Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Process PoolWorker-4:
# Process PoolWorker-10:
# Process PoolWorker-11:
# Process PoolWorker-12:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     return recv()
#     racquire()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
# KeyboardInterrupt
# KeyboardInterrupt
#     racquire()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
# KeyboardInterrupt
#     racquire()
# KeyboardInterrupt
# Process PoolWorker-16:
# Process PoolWorker-14:
# Process PoolWorker-13:
# Process PoolWorker-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     task = get()
#     racquire()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
# KeyboardInterrupt
#     return recv()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
# KeyboardInterrupt
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# Process PoolWorker-20:
# Process PoolWorker-19:
# Process PoolWorker-18:
# Process PoolWorker-17:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#     task = get()
#     task = get()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     return recv()
#     racquire()
#     racquire()
# KeyboardInterrupt
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process PoolWorker-24:
# Process PoolWorker-21:
# Process PoolWorker-22:
# Process PoolWorker-23:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#     return recv()
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#     racquire()
# KeyboardInterrupt
# Process PoolWorker-27:
# Process PoolWorker-28:
# Process PoolWorker-26:
# Process PoolWorker-25:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 267, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     racquire()
#     task = get()
# KeyboardInterrupt
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     task = get()
#     racquire()
#     task = get()
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
# KeyboardInterrupt
#   File "/Users/masanori/.pyenv/versions/2.7.14/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     return recv()
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt

# %%
parameters = {
        'hidden_layer_sizes': [(100,),(200,),(10,),(1000)],
}
gsc = GridSearchCV(MLPClassifier(), parameters,cv=3, scoring='accuracy')
gsc.fit(train_data[predictors], train_data["Survived"])

# %%
gsc.grid_scores_

# %%
gsc.best_params_

# %%
alg = RandomForestClassifier()
alg.fit(train_data[predictors], train_data["Survived"])

predictions = alg.predict(test_data[predictors])

submission = pd.DataFrame({
        "PassengerId": test_data["PassengerId"],
        "Survived": predictions
    })

submission.to_csv('submission.csv', index=False)

# %%
parameters = {
        'n_estimators'      : [5, 10, 20, 30, 50, 100, 300],
        'max_depth'         : [3, 5, 10, 15, 20, 25, 30, 40, 50, 100],
        'random_state'      : [0],
}
gsc = z(RandomForestClassifier(), parameters,cv=3)
gsc.fit(train_data[predictors], train_data["Survived"])
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [5, 10, 20, 30, 50, 100, 300], 'random_state': [0], 'max_depth': [3, 5, 10, 15, 20, 25, 30, 40, 50, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
gsc.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 300, 'random_state': 0}

# %%
model = RandomForestClassifier(max_depth=gsc.best_params_['max_depth'],n_estimators=gsc.best_params_['n_estimators'],random_state=gsc.best_params_['random_state'],n_jobs=-1)
cross_val_score(model, train_data[predictors], train_data["Survived"],  cv=3).mean()
# Out:
# 0.8215488215488215

# %%
alg = RandomForestClassifier(verbose= True,max_depth=gsc.best_params_['max_depth'],n_estimators=gsc.best_params_['n_estimators'],random_state=gsc.best_params_['random_state'],n_jobs=-1)
alg.fit(train_data[predictors], train_data["Survived"])

predictions = alg.predict(test_data[predictors])

submission = pd.DataFrame({
        "PassengerId": test_data["PassengerId"],
        "Survived": predictions
    })

submission.to_csv('submission.csv', index=False)
# Out:
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed:    0.1s finished
